# %%
import pandas as pd
import requests
import json

# %%
url = 'https://caelum-online-public.s3.amazonaws.com/2929-pandas/informacoes.json'
df = pd.read_json(url)
df
# Out:
#    nome  idade                                          enderecos
# 0  João     28  {'tipo': 'casa', 'rua': 'Rua A', 'numero': 123...
# 1  João     28  {'tipo': 'trabalho', 'rua': 'Rua B', 'numero':...

# %%
pd.json_normalize(df['enderecos'])
# Out:
#        tipo    rua  numero          cidade
# 0      casa  Rua A     123       São Paulo
# 1  trabalho  Rua B     456  Rio de Janeiro

# %%
response = requests.get(url)
dados_brutos = json.loads(response.text)

# %%
pd.json_normalize(dados_brutos, record_path='enderecos', meta=['nome', 'idade'])
# Out:
#        tipo    rua  numero          cidade  nome idade
# 0      casa  Rua A     123       São Paulo  João    28
# 1  trabalho  Rua B     456  Rio de Janeiro  João    28

# %%
json_df = pd.read_json("https://caelum-online-public.s3.amazonaws.com/2929-pandas/dados.json")
json_df
# Out:
#                                              pessoas
# 0  {'nome': 'João', 'idade': '25', 'endereco': {'...
# 1  {'nome': 'Maria', 'idade': 30, 'endereco': {'r...

# %%
json_df = pd.json_normalize(json_df['pessoas'])
json_df
# Out:
#     nome idade                     telefones endereco.rua  endereco.numero  \
# 0   João    25  [11 1111-1111, 11 2222-2222]        Rua A              123
# 1  Maria    30                [21 3333-3333]                           456
#
#   endereco.cidade
# 0       São Paulo
# 1  Rio de Janeiro

# %%
json_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nome             2 non-null      object
#  1   idade            2 non-null      object
#  2   telefones        2 non-null      object
#  3   endereco.rua     2 non-null      object
#  4   endereco.numero  2 non-null      int64
#  5   endereco.cidade  2 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 228.0+ bytes

# %%
json_df['idade'] = json_df['idade'].astype('int64')
json_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nome             2 non-null      object
#  1   idade            2 non-null      int64
#  2   telefones        2 non-null      object
#  3   endereco.rua     2 non-null      object
#  4   endereco.numero  2 non-null      int64
#  5   endereco.cidade  2 non-null      object
# dtypes: int64(2), object(4)
# memory usage: 228.0+ bytes

# %%
json_df[json_df['endereco.rua'] != '']
# Out:
#    nome  idade                     telefones endereco.rua  endereco.numero  \
# 0  João     25  [11 1111-1111, 11 2222-2222]        Rua A              123
#
#   endereco.cidade
# 0       São Paulo

# %% [markdown]
# <h1>Desafio 3</h1>

# %%
desafio3 = pd.read_json("https://caelum-online-public.s3.amazonaws.com/2929-pandas/cursos_cadastrados.json")
desafio3.head()
# Out:
#                              curso      categoria carga_horaria concluintes  \
# 0         Introdução à programação    Programação      20 horas         100
# 1            Excel para iniciantes  Produtividade          None        None
# 2  Marketing digital para negócios      Marketing      30 horas          75
# 3          Inteligência artificial    Programação      40 horas
# 4             Inglês para negócios        Idiomas      20 horas          30
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1        None           None
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
#
#                                            descricao  preco  \
# 0        Curso introdutório à programação com Python   99.9
# 1                                               None    NaN
# 2                    Curso introdutório em marketing   89.9
# 3  Curso avançado sobre inteligência artificial c...  129.9
# 4                      Curso de inglês para negócios   69.9
#
# ...

# %%
response = requests.get("https://caelum-online-public.s3.amazonaws.com/2929-pandas/cursos_cadastrados.json")
desafio3 = json.loads(response.text)

# %%
lista_meta = ['curso','categoria', 'carga_horaria',	'concluintes', 'data_inicio', 'data_conclusao', 'descricao', 'preco']

# %%
desafio3 = pd.json_normalize(desafio3)
desafio3
# Out:
#                              curso      categoria carga_horaria concluintes  \
# 0         Introdução à programação    Programação      20 horas         100
# 1            Excel para iniciantes  Produtividade          None        None
# 2  Marketing digital para negócios      Marketing      30 horas          75
# 3          Inteligência artificial    Programação      40 horas
# 4             Inglês para negócios        Idiomas      20 horas          30
# 5         Introdução à programação    Programação      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1        None           None
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
# 5  2022-01-01     2022-01-20
#
#                                            descricao  preco  instrutor.nome  \
# 0        Curso introdutório à programação com Python  99.90      João Silva
# 1                                               None   None  Maria Oliveira
# ...

# %%
desafio3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   curso               6 non-null      object
#  1   categoria           6 non-null      object
#  2   carga_horaria       5 non-null      object
#  3   concluintes         5 non-null      object
#  4   data_inicio         5 non-null      object
#  5   data_conclusao      5 non-null      object
#  6   descricao           5 non-null      object
#  7   preco               5 non-null      object
#  8   instrutor.nome      6 non-null      object
#  9   instrutor.email     6 non-null      object
#  10  instrutor.telefone  6 non-null      object
# dtypes: object(11)
# memory usage: 660.0+ bytes

# %%
desafio3 = desafio3.dropna()
desafio3
# Out:
#                              curso    categoria carga_horaria concluintes  \
# 0         Introdução à programação  Programação      20 horas         100
# 2  Marketing digital para negócios    Marketing      30 horas          75
# 3          Inteligência artificial  Programação      40 horas
# 4             Inglês para negócios      Idiomas      20 horas          30
# 5         Introdução à programação  Programação      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
# 5  2022-01-01     2022-01-20
#
#                                            descricao  preco instrutor.nome  \
# 0        Curso introdutório à programação com Python  99.90     João Silva
# 2                    Curso introdutório em marketing   89.9     Ana Santos
# 3  Curso avançado sobre inteligência artificial c...  129.9
# 4                      Curso de inglês para negócios   69.9     John Smith
# ...

# %%
desafio3.replace('', pd.NA, inplace=True)
desafio3
# Out:
# C:\Users\Douglas Tinoco\AppData\Local\Temp\ipykernel_10344\4162148174.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desafio3.replace('', pd.NA, inplace=True)
#                              curso    categoria carga_horaria concluintes  \
# 0         Introdução à programação  Programação      20 horas         100
# 2  Marketing digital para negócios    Marketing      30 horas          75
# 3          Inteligência artificial  Programação      40 horas        <NA>
# 4             Inglês para negócios      Idiomas      20 horas          30
# 5         Introdução à programação  Programação      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 2  2022-03-01     2022-03-31
# 3  2022-04-01           <NA>
# 4        <NA>           <NA>
# ...

# %%
desafio3.dropna(inplace=True)
desafio3
# Out:
# C:\Users\Douglas Tinoco\AppData\Local\Temp\ipykernel_10344\3898952825.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desafio3.dropna(inplace=True)
#                              curso    categoria carga_horaria concluintes  \
# 0         Introdução à programação  Programação      20 horas         100
# 2  Marketing digital para negócios    Marketing      30 horas          75
# 5         Introdução à programação  Programação      20 horas         100
#
#   data_inicio data_conclusao                                    descricao  \
# 0  2022-01-01     2022-01-20  Curso introdutório à programação com Python
# 2  2022-03-01     2022-03-31              Curso introdutório em marketing
# 5  2022-01-01     2022-01-20  Curso introdutório à programação com Python
#
# ...

# %%
desafio3.duplicated()
# Out:
# 0    False
# 2    False
# 5     True
# dtype: bool

# %%
desafio3.drop_duplicates(inplace=True)
desafio3
# Out:
# C:\Users\Douglas Tinoco\AppData\Local\Temp\ipykernel_10344\983235673.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desafio3.drop_duplicates(inplace=True)
#                              curso    categoria carga_horaria concluintes  \
# 0         Introdução à programação  Programação      20 horas         100
# 2  Marketing digital para negócios    Marketing      30 horas          75
#
#   data_inicio data_conclusao                                    descricao  \
# 0  2022-01-01     2022-01-20  Curso introdutório à programação com Python
# 2  2022-03-01     2022-03-31              Curso introdutório em marketing
#
#    preco instrutor.nome                instrutor.email instrutor.telefone
# 0  99.90     João Silva  joao.silva@emailaleatorio.com     (11) 9999-9999
# ...

# %%
desafio3.reset_index(drop=True, inplace=True)

# %%
desafio3['preco'] = desafio3['preco'].astype('Float64')
desafio3['concluintes'] = desafio3['concluintes'].astype('Int64')
desafio3['data_inicio'] = pd.to_datetime(desafio3['data_inicio'])
desafio3['data_conclusao'] = pd.to_datetime(desafio3['data_conclusao'])
# Out:
# C:\Users\Douglas Tinoco\AppData\Local\Temp\ipykernel_10344\3371053671.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desafio3['preco'] = desafio3['preco'].astype('Float64')
# C:\Users\Douglas Tinoco\AppData\Local\Temp\ipykernel_10344\3371053671.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desafio3['concluintes'] = desafio3['concluintes'].astype('Int64')
# C:\Users\Douglas Tinoco\AppData\Local\Temp\ipykernel_10344\3371053671.py:3: SettingWithCopyWarning:
# ...

# %%
desafio3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   curso               2 non-null      object
#  1   categoria           2 non-null      object
#  2   carga_horaria       2 non-null      object
#  3   concluintes         2 non-null      Int64
#  4   data_inicio         2 non-null      datetime64[ns]
#  5   data_conclusao      2 non-null      datetime64[ns]
#  6   descricao           2 non-null      object
#  7   preco               2 non-null      Float64
#  8   instrutor.nome      2 non-null      object
#  9   instrutor.email     2 non-null      object
#  10  instrutor.telefone  2 non-null      object
# dtypes: Float64(1), Int64(1), datetime64[ns](2), object(7)
# memory usage: 312.0+ bytes
